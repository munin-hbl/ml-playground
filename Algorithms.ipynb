# %% [markdown]
# This notebook will be used to learn and review algorithms

# %%
#fizz buzz algo

def fizzbuzz(n):
    for n in range(n):
        print("Fizz"*(not n % 3) + "Buzz"*(not n % 5) or n)
fizzbuzz(20)
# Out:
# FizzBuzz
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
